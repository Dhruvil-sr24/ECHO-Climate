# %%
import torch
import requests
import inflect
from transformers import (
    AutoModelForSpeechSeq2Seq, 
    AutoProcessor, 
    pipeline, 
    SpeechT5Processor, 
    SpeechT5ForTextToSpeech, 
    SpeechT5HifiGan
)
from datasets import load_dataset
import soundfile as sf
import librosa

# %%
# Set device and data type for optimized performance
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

# Load models once and reuse them for efficiency
def load_models():
    # Load the speech-to-text model (Whisper)
    model_id = "openai/whisper-tiny.en"
    model = AutoModelForSpeechSeq2Seq.from_pretrained(
        model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
    ).to(device)
    processor = AutoProcessor.from_pretrained(model_id)
    
    # Create a pipeline for automatic speech recognition (ASR)
    pipe = pipeline(
        "automatic-speech-recognition",
        model=model,
        tokenizer=processor.tokenizer,
        feature_extractor=processor.feature_extractor,
        torch_dtype=torch_dtype,  # Use mixed precision for faster processing
        device=0 if torch.cuda.is_available() else -1,  # Use GPU if available
    )
    
    # Load text-to-speech (TTS) models
    processor_tts = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")
    model_tts = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts").to(device)
    vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan").to(device)
    
    return pipe, processor_tts, model_tts, vocoder

# Optimized speech-to-text processing with mixed precision
def process_sample(pipe, audio_path):
    with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):  # Mixed precision
        result = pipe(audio_path)  # Perform speech recognition
    return result['text']

# API Call to get city temperature (optimized)
def get_city_temperature(city):
    api_key = "e7777b4e947b1311b4d5fbe5a004be21"
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        temperature = data['main']['temp']
        humidity = data['main']['humidity']
        
        # Use inflect engine to convert numbers to words
        p = inflect.engine()
        txt_temp = p.number_to_words(temperature)
        humidity_temp = p.number_to_words(humidity)
        
        return f"{txt_temp} celsius and {humidity_temp} percent."
    else:
        return "Sorry, I couldn't retrieve the temperature for that city."

# Text-to-speech function
def generate_speech(text, processor_tts, model_tts, vocoder):
    # Prepare text inputs
    inputs = processor_tts(text=text, return_tensors="pt").to(device)
    
    # Load speaker embeddings only once to avoid reloading
    embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
    speaker_embeddings = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0).to(device)
    
    # Generate speech
    with torch.no_grad():  # Disable gradients for faster inference
        speech = model_tts.generate_speech(inputs["input_ids"], speaker_embeddings, vocoder=vocoder)
    
    # Save speech to file
    sf.write("speech.wav", speech.cpu().numpy(), samplerate=16000)






# Main function to handle speech-to-text, get data, and text-to-speech
def main():

    

    pipe, processor_tts, model_tts, vocoder = load_models()
    
    # Process audio input for speech-to-text
    sample = "recorded_audio.wav"
    jsn_ot = process_sample(pipe, sample)
    print(f"Transcribed Text: {jsn_ot}")
    
    # Extract city name and get temperature data
    jsn_ot_api = "what's the temperature in mumbai"
    words = jsn_ot_api.split()
    city = words[-1]  # Assuming last word is the city
    city_temperature_humid = get_city_temperature(city)
    
    # Prepare the final text for TTS
    final_text = f"{city_temperature_humid}"
    print(f"Final Text for TTS: {final_text}")
    
    # Generate speech from text
    generate_speech(final_text, processor_tts, model_tts, vocoder)
    print("Speech generated and saved as 'speech.wav'")

    # int16_speech_array = generate_speech(final_text, processor_tts, model_tts, vocoder)
    # print(f"Generated signed 16-bit integer array for ESP32.{int16_speech_array}",)



# Execute the main function
# if __name__ == "__main__":
main()
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_14320\402981480.py:33: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):  # Mixed precision
# Transcribed Text:  The weather in Surat
# Final Text for TTS: twenty-nine point nine nine celsius and sixty-six percent.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 111
#     102     print("Speech generated and saved as 'speech.wav'")
#     104     # int16_speech_array = generate_speech(final_text, processor_tts, model_tts, vocoder)
#     105     # print(f"Generated signed 16-bit integer array for ESP32.{int16_speech_array}",)
#     106
#    (...)
#     109 # Execute the main function
#     110 # if __name__ == "__main__":
# --> 111 main()
#
# Cell In[8], line 101, in main()
#      98 print(f"Final Text for TTS: {final_text}")
#     100 # Generate speech from text
# --> 101 generate_speech(final_text, processor_tts, model_tts, vocoder)
#     102 print("Speech generated and saved as 'speech.wav'")
#
# Cell In[8], line 63, in generate_speech(text, processor_tts, model_tts, vocoder)
#      60 inputs = processor_tts(text=text, return_tensors="pt").to(device)
#      62 # Load speaker embeddings only once to avoid reloading
# ---> 63 embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
#      64 speaker_embeddings = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0).to(device)
#      66 # Generate speech
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\load.py:2074, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2069 verification_mode = VerificationMode(
#    2070     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2071 )
#    2073 # Create a dataset builder
# -> 2074 builder_instance = load_dataset_builder(
#    2075     path=path,
#    2076     name=name,
#    2077     data_dir=data_dir,
#    2078     data_files=data_files,
#    2079     cache_dir=cache_dir,
#    2080     features=features,
#    2081     download_config=download_config,
#    2082     download_mode=download_mode,
#    2083     revision=revision,
#    2084     token=token,
#    2085     storage_options=storage_options,
#    2086     trust_remote_code=trust_remote_code,
#    2087     _require_default_config_name=name is None,
#    2088     **config_kwargs,
#    2089 )
#    2091 # Return iterable dataset in case of streaming
#    2092 if streaming:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\load.py:1846, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    1831 # Instantiate the dataset builder
#    1832 builder_instance: DatasetBuilder = builder_cls(
#    1833     cache_dir=cache_dir,
#    1834     dataset_name=dataset_name,
#    (...)
#    1844     **config_kwargs,
#    1845 )
# -> 1846 builder_instance._use_legacy_cache_dir_if_possible(dataset_module)
#    1848 return builder_instance
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\builder.py:642, in DatasetBuilder._use_legacy_cache_dir_if_possible(self, dataset_module)
#     639 def _use_legacy_cache_dir_if_possible(self, dataset_module: "DatasetModule"):
#     640     # Check for the legacy cache directory template (datasets<3.0.0)
#     641     self._legacy_relative_data_dir = (
# --> 642         self._check_legacy_cache2(dataset_module) or self._check_legacy_cache() or None
#     643     )
#     644     self._cache_dir = self._build_cache_dir()
#     645     self._output_dir = self._cache_dir
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\builder.py:486, in DatasetBuilder._check_legacy_cache2(self, dataset_module)
#     484 namespace = self.repo_id.split("/")[0] if self.repo_id and self.repo_id.count("/") > 0 else None
#     485 with patch.object(Pickler, "_legacy_no_dict_keys_sorting", True):
# --> 486     config_id = self.config.name + "-" + Hasher.hash({"data_files": self.config.data_files})
#     487 hash = _PACKAGED_DATASETS_MODULES_2_15_HASHES.get(self.name, "missing")
#     488 if (
#     489     dataset_module.builder_configs_parameters.metadata_configs
#     490     and self.config.name in dataset_module.builder_configs_parameters.metadata_configs
#     491 ):
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\fingerprint.py:188, in Hasher.hash(cls, value)
#     186 @classmethod
#     187 def hash(cls, value: Any) -> str:
# --> 188     return cls.hash_bytes(dumps(value))
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:109, in dumps(obj)
#     107 """Pickle an object to a string."""
#     108 file = BytesIO()
# --> 109 dump(obj, file)
#     110 return file.getvalue()
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:103, in dump(obj, file)
#     101 def dump(obj, file):
#     102     """Pickle an object to a file."""
# --> 103     Pickler(file, recurse=True).dump(obj)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:420, in Pickler.dump(self, obj)
#     418 def dump(self, obj): #NOTE: if settings change, need to update attributes
#     419     logger.trace_setup(self)
# --> 420     StockPickler.dump(self, obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:481, in _Pickler.dump(self, obj)
#     479 if self.proto >= 4:
#     480     self.framer.start_framing()
# --> 481 self.save(obj)
#     482 self.write(STOP)
#     483 self.framer.end_framing()
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:966, in _Pickler.save_dict(self, obj)
#     963     self.write(MARK + DICT)
#     965 self.memoize(obj)
# --> 966 self._batch_setitems(obj.items())
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:74, in Pickler._batch_setitems(self, items)
#      72 def _batch_setitems(self, items):
#      73     if self._legacy_no_dict_keys_sorting:
# ---> 74         return super()._batch_setitems(items)
#      75     # Ignore the order of keys in a dict
#      76     try:
#      77         # Faster, but fails for unorderable elements
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:995, in _Pickler._batch_setitems(self, items)
#     993     k, v = tmp[0]
#     994     save(k)
# --> 995     save(v)
#     996     write(SETITEM)
#     997 # else tmp is empty, and we're done
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:597, in _Pickler.save(self, obj, save_persistent_id)
#     593     raise PicklingError("Tuple returned by %s must have "
#     594                         "two to six elements" % reduce)
#     596 # Save the reduce() output and finally memoize the object
# --> 597 self.save_reduce(obj=obj, *rv)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:681, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     678     raise PicklingError(
#     679         "args[0] from __newobj__ args has the wrong class")
#     680 args = args[1:]
# --> 681 save(cls)
#     682 save(args)
#     683 write(NEWOBJ)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1846, in save_type(pickler, obj, postproc_list)
#    1843         else:
#    1844             _dict_update = None
# -> 1846         _save_with_postproc(pickler, (new_class, (
#    1847             obj.__name__, obj.__orig_bases__, _metadict, _dict_update
#    1848         )), obj=obj, postproc_list=postproc_list)
#    1849     logger.trace(pickler, "# T2")
#    1850 else:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1098, in _save_with_postproc(pickler, reduction, is_pickler_dill, obj, postproc_list)
#    1095     pickler._postproc[id(obj)] = postproc_list
#    1097 # TODO: Use state_setter in Python 3.8 to allow for faster cPickle implementations
# -> 1098 pickler.save_reduce(*reduction, obj=obj)
#    1100 if is_pickler_dill:
#    1101     # pickler.x -= 1
#    1102     # print(pickler.x*' ', 'pop', obj, id(obj))
#    1103     postproc = pickler._postproc.pop(id(obj))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:686, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     684 else:
#     685     save(func)
# --> 686     save(args)
#     687     write(REDUCE)
#     689 if obj is not None:
#     690     # If the object is already in the memo, this means it is
#     691     # recursive. In this case, throw away everything we put on the
#     692     # stack, and fetch the object back from the memo.
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:896, in _Pickler.save_tuple(self, obj)
#     894 write(MARK)
#     895 for element in obj:
# --> 896     save(element)
#     898 if id(obj) in memo:
#     899     # Subtle.  d was not in memo when we entered save_tuple(), so
#     900     # the process of saving the tuple's elements must have saved
#    (...)
#     904     # could have been done in the "for element" loop instead, but
#     905     # recursive tuples are a rare thing.
#     906     get = self.get(memo[id(obj)][0])
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:881, in _Pickler.save_tuple(self, obj)
#     879 if n <= 3 and self.proto >= 2:
#     880     for element in obj:
# --> 881         save(element)
#     882     # Subtle.  Same as in the big comment below.
#     883     if id(obj) in memo:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1305, in save_generic_alias(pickler, obj)
#    1303 else:
#    1304     logger.trace(pickler, "Ga2: %s", obj)
# -> 1305     StockPickler.save_reduce(pickler, *obj.__reduce__(), obj=obj)
#    1306     logger.trace(pickler, "# Ga2")
#    1307 return
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:686, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     684 else:
#     685     save(func)
# --> 686     save(args)
#     687     write(REDUCE)
#     689 if obj is not None:
#     690     # If the object is already in the memo, this means it is
#     691     # recursive. In this case, throw away everything we put on the
#     692     # stack, and fetch the object back from the memo.
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:881, in _Pickler.save_tuple(self, obj)
#     879 if n <= 3 and self.proto >= 2:
#     880     for element in obj:
# --> 881         save(element)
#     882     # Subtle.  Same as in the big comment below.
#     883     if id(obj) in memo:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:881, in _Pickler.save_tuple(self, obj)
#     879 if n <= 3 and self.proto >= 2:
#     880     for element in obj:
# --> 881         save(element)
#     882     # Subtle.  Same as in the big comment below.
#     883     if id(obj) in memo:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1846, in save_type(pickler, obj, postproc_list)
#    1843         else:
#    1844             _dict_update = None
# -> 1846         _save_with_postproc(pickler, (new_class, (
#    1847             obj.__name__, obj.__orig_bases__, _metadict, _dict_update
#    1848         )), obj=obj, postproc_list=postproc_list)
#    1849     logger.trace(pickler, "# T2")
#    1850 else:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1098, in _save_with_postproc(pickler, reduction, is_pickler_dill, obj, postproc_list)
#    1095     pickler._postproc[id(obj)] = postproc_list
#    1097 # TODO: Use state_setter in Python 3.8 to allow for faster cPickle implementations
# -> 1098 pickler.save_reduce(*reduction, obj=obj)
#    1100 if is_pickler_dill:
#    1101     # pickler.x -= 1
#    1102     # print(pickler.x*' ', 'pop', obj, id(obj))
#    1103     postproc = pickler._postproc.pop(id(obj))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:686, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     684 else:
#     685     save(func)
# --> 686     save(args)
#     687     write(REDUCE)
#     689 if obj is not None:
#     690     # If the object is already in the memo, this means it is
#     691     # recursive. In this case, throw away everything we put on the
#     692     # stack, and fetch the object back from the memo.
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:896, in _Pickler.save_tuple(self, obj)
#     894 write(MARK)
#     895 for element in obj:
# --> 896     save(element)
#     898 if id(obj) in memo:
#     899     # Subtle.  d was not in memo when we entered save_tuple(), so
#     900     # the process of saving the tuple's elements must have saved
#    (...)
#     904     # could have been done in the "for element" loop instead, but
#     905     # recursive tuples are a rare thing.
#     906     get = self.get(memo[id(obj)][0])
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:597, in _Pickler.save(self, obj, save_persistent_id)
#     593     raise PicklingError("Tuple returned by %s must have "
#     594                         "two to six elements" % reduce)
#     596 # Save the reduce() output and finally memoize the object
# --> 597 self.save_reduce(obj=obj, *rv)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:711, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     709 if state is not None:
#     710     if state_setter is None:
# --> 711         save(state)
#     712         write(BUILD)
#     713     else:
#     714         # If a state_setter is specified, call it instead of load_build
#     715         # to update obj's with its previous state.
#     716         # First, push state_setter and its tuple of expected arguments
#     717         # (obj, state) onto the stack.
#
#     [... skipping similar frames: Pickler.save at line 70 (1 times), Pickler.save at line 414 (1 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:896, in _Pickler.save_tuple(self, obj)
#     894 write(MARK)
#     895 for element in obj:
# --> 896     save(element)
#     898 if id(obj) in memo:
#     899     # Subtle.  d was not in memo when we entered save_tuple(), so
#     900     # the process of saving the tuple's elements must have saved
#    (...)
#     904     # could have been done in the "for element" loop instead, but
#     905     # recursive tuples are a rare thing.
#     906     get = self.get(memo[id(obj)][0])
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:966, in _Pickler.save_dict(self, obj)
#     963     self.write(MARK + DICT)
#     965 self.memoize(obj)
# --> 966 self._batch_setitems(obj.items())
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:74, in Pickler._batch_setitems(self, items)
#      72 def _batch_setitems(self, items):
#      73     if self._legacy_no_dict_keys_sorting:
# ---> 74         return super()._batch_setitems(items)
#      75     # Ignore the order of keys in a dict
#      76     try:
#      77         # Faster, but fails for unorderable elements
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:995, in _Pickler._batch_setitems(self, items)
#     993     k, v = tmp[0]
#     994     save(k)
# --> 995     save(v)
#     996     write(SETITEM)
#     997 # else tmp is empty, and we're done
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:966, in _Pickler.save_dict(self, obj)
#     963     self.write(MARK + DICT)
#     965 self.memoize(obj)
# --> 966 self._batch_setitems(obj.items())
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:74, in Pickler._batch_setitems(self, items)
#      72 def _batch_setitems(self, items):
#      73     if self._legacy_no_dict_keys_sorting:
# ---> 74         return super()._batch_setitems(items)
#      75     # Ignore the order of keys in a dict
#      76     try:
#      77         # Faster, but fails for unorderable elements
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:990, in _Pickler._batch_setitems(self, items)
#     988     for k, v in tmp:
#     989         save(k)
# --> 990         save(v)
#     991     write(SETITEMS)
#     992 elif n:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1897, in save_classmethod(pickler, obj)
#    1887 orig_func = obj.__func__
#    1889 # if type(obj.__dict__) is dict:
#    1890 #     if obj.__dict__:
#    1891 #         state = obj.__dict__
#    (...)
#    1894 # else:
#    1895 #     state = (None, {'__dict__', obj.__dict__})
# -> 1897 pickler.save_reduce(type(obj), (orig_func,), obj=obj)
#    1898 logger.trace(pickler, "# Cm")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:686, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     684 else:
#     685     save(func)
# --> 686     save(args)
#     687     write(REDUCE)
#     689 if obj is not None:
#     690     # If the object is already in the memo, this means it is
#     691     # recursive. In this case, throw away everything we put on the
#     692     # stack, and fetch the object back from the memo.
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:881, in _Pickler.save_tuple(self, obj)
#     879 if n <= 3 and self.proto >= 2:
#     880     for element in obj:
# --> 881         save(element)
#     882     # Subtle.  Same as in the big comment below.
#     883     if id(obj) in memo:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1985, in save_function(pickler, obj)
#    1982 if state_dict:
#    1983     state = state, state_dict
# -> 1985 _save_with_postproc(pickler, (_create_function, (
#    1986         obj.__code__, globs, obj.__name__, obj.__defaults__,
#    1987         closure
#    1988 ), state), obj=obj, postproc_list=postproc_list)
#    1990 # Lift closure cell update to earliest function (#458)
#    1991 if _postproc:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1112, in _save_with_postproc(pickler, reduction, is_pickler_dill, obj, postproc_list)
#    1110 if source:
#    1111     pickler.write(pickler.get(pickler.memo[id(dest)][0]))
# -> 1112     pickler._batch_setitems(iter(source.items()))
#    1113 else:
#    1114     # Updating with an empty dictionary. Same as doing nothing.
#    1115     continue
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:74, in Pickler._batch_setitems(self, items)
#      72 def _batch_setitems(self, items):
#      73     if self._legacy_no_dict_keys_sorting:
# ---> 74         return super()._batch_setitems(items)
#      75     # Ignore the order of keys in a dict
#      76     try:
#      77         # Faster, but fails for unorderable elements
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:990, in _Pickler._batch_setitems(self, items)
#     988     for k, v in tmp:
#     989         save(k)
# --> 990         save(v)
#     991     write(SETITEMS)
#     992 elif n:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1985, in save_function(pickler, obj)
#    1982 if state_dict:
#    1983     state = state, state_dict
# -> 1985 _save_with_postproc(pickler, (_create_function, (
#    1986         obj.__code__, globs, obj.__name__, obj.__defaults__,
#    1987         closure
#    1988 ), state), obj=obj, postproc_list=postproc_list)
#    1990 # Lift closure cell update to earliest function (#458)
#    1991 if _postproc:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1112, in _save_with_postproc(pickler, reduction, is_pickler_dill, obj, postproc_list)
#    1110 if source:
#    1111     pickler.write(pickler.get(pickler.memo[id(dest)][0]))
# -> 1112     pickler._batch_setitems(iter(source.items()))
#    1113 else:
#    1114     # Updating with an empty dictionary. Same as doing nothing.
#    1115     continue
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:74, in Pickler._batch_setitems(self, items)
#      72 def _batch_setitems(self, items):
#      73     if self._legacy_no_dict_keys_sorting:
# ---> 74         return super()._batch_setitems(items)
#      75     # Ignore the order of keys in a dict
#      76     try:
#      77         # Faster, but fails for unorderable elements
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:990, in _Pickler._batch_setitems(self, items)
#     988     for k, v in tmp:
#     989         save(k)
# --> 990         save(v)
#     991     write(SETITEMS)
#     992 elif n:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1832, in save_type(pickler, obj, postproc_list)
#    1829     postproc_list.append((setattr, (obj, '__qualname__', qualname)))
#    1831 if not hasattr(obj, '__orig_bases__'):
# -> 1832     _save_with_postproc(pickler, (_create_type, (
#    1833         type(obj), obj.__name__, obj.__bases__, _dict
#    1834     )), obj=obj, postproc_list=postproc_list)
#    1835 else:
#    1836     # This case will always work, but might be overkill.
#    1837     _metadict = {
#    1838         'metaclass': type(obj)
#    1839     }
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1098, in _save_with_postproc(pickler, reduction, is_pickler_dill, obj, postproc_list)
#    1095     pickler._postproc[id(obj)] = postproc_list
#    1097 # TODO: Use state_setter in Python 3.8 to allow for faster cPickle implementations
# -> 1098 pickler.save_reduce(*reduction, obj=obj)
#    1100 if is_pickler_dill:
#    1101     # pickler.x -= 1
#    1102     # print(pickler.x*' ', 'pop', obj, id(obj))
#    1103     postproc = pickler._postproc.pop(id(obj))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:686, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     684 else:
#     685     save(func)
# --> 686     save(args)
#     687     write(REDUCE)
#     689 if obj is not None:
#     690     # If the object is already in the memo, this means it is
#     691     # recursive. In this case, throw away everything we put on the
#     692     # stack, and fetch the object back from the memo.
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:896, in _Pickler.save_tuple(self, obj)
#     894 write(MARK)
#     895 for element in obj:
# --> 896     save(element)
#     898 if id(obj) in memo:
#     899     # Subtle.  d was not in memo when we entered save_tuple(), so
#     900     # the process of saving the tuple's elements must have saved
#    (...)
#     904     # could have been done in the "for element" loop instead, but
#     905     # recursive tuples are a rare thing.
#     906     get = self.get(memo[id(obj)][0])
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:966, in _Pickler.save_dict(self, obj)
#     963     self.write(MARK + DICT)
#     965 self.memoize(obj)
# --> 966 self._batch_setitems(obj.items())
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:74, in Pickler._batch_setitems(self, items)
#      72 def _batch_setitems(self, items):
#      73     if self._legacy_no_dict_keys_sorting:
# ---> 74         return super()._batch_setitems(items)
#      75     # Ignore the order of keys in a dict
#      76     try:
#      77         # Faster, but fails for unorderable elements
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:990, in _Pickler._batch_setitems(self, items)
#     988     for k, v in tmp:
#     989         save(k)
# --> 990         save(v)
#     991     write(SETITEMS)
#     992 elif n:
#
#     [... skipping similar frames: Pickler.save at line 70 (1 times), Pickler.save at line 414 (1 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:597, in _Pickler.save(self, obj, save_persistent_id)
#     593     raise PicklingError("Tuple returned by %s must have "
#     594                         "two to six elements" % reduce)
#     596 # Save the reduce() output and finally memoize the object
# --> 597 self.save_reduce(obj=obj, *rv)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:711, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     709 if state is not None:
#     710     if state_setter is None:
# --> 711         save(state)
#     712         write(BUILD)
#     713     else:
#     714         # If a state_setter is specified, call it instead of load_build
#     715         # to update obj's with its previous state.
#     716         # First, push state_setter and its tuple of expected arguments
#     717         # (obj, state) onto the stack.
#
#     [... skipping similar frames: Pickler.save at line 70 (1 times), Pickler.save at line 414 (1 times), _Pickler.save at line 554 (1 times)]
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:966, in _Pickler.save_dict(self, obj)
#     963     self.write(MARK + DICT)
#     965 self.memoize(obj)
# --> 966 self._batch_setitems(obj.items())
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:74, in Pickler._batch_setitems(self, items)
#      72 def _batch_setitems(self, items):
#      73     if self._legacy_no_dict_keys_sorting:
# ---> 74         return super()._batch_setitems(items)
#      75     # Ignore the order of keys in a dict
#      76     try:
#      77         # Faster, but fails for unorderable elements
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:990, in _Pickler._batch_setitems(self, items)
#     988     for k, v in tmp:
#     989         save(k)
# --> 990         save(v)
#     991     write(SETITEMS)
#     992 elif n:
#
#     [... skipping similar frames: Pickler.save at line 70 (1 times), Pickler.save at line 414 (1 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:597, in _Pickler.save(self, obj, save_persistent_id)
#     593     raise PicklingError("Tuple returned by %s must have "
#     594                         "two to six elements" % reduce)
#     596 # Save the reduce() output and finally memoize the object
# --> 597 self.save_reduce(obj=obj, *rv)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:711, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     709 if state is not None:
#     710     if state_setter is None:
# --> 711         save(state)
#     712         write(BUILD)
#     713     else:
#     714         # If a state_setter is specified, call it instead of load_build
#     715         # to update obj's with its previous state.
#     716         # First, push state_setter and its tuple of expected arguments
#     717         # (obj, state) onto the stack.
#
#     [... skipping similar frames: Pickler.save at line 70 (5 times), Pickler.save at line 414 (5 times), Pickler._batch_setitems at line 74 (3 times), _Pickler._batch_setitems at line 990 (3 times), _Pickler.save at line 554 (3 times), _Pickler.save_dict at line 966 (3 times), save_module_dict at line 1217 (3 times), _Pickler.save at line 597 (1 times), _Pickler.save_reduce at line 711 (1 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:597, in _Pickler.save(self, obj, save_persistent_id)
#     593     raise PicklingError("Tuple returned by %s must have "
#     594                         "two to six elements" % reduce)
#     596 # Save the reduce() output and finally memoize the object
# --> 597 self.save_reduce(obj=obj, *rv)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:711, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     709 if state is not None:
#     710     if state_setter is None:
# --> 711         save(state)
#     712         write(BUILD)
#     713     else:
#     714         # If a state_setter is specified, call it instead of load_build
#     715         # to update obj's with its previous state.
#     716         # First, push state_setter and its tuple of expected arguments
#     717         # (obj, state) onto the stack.
#
#     [... skipping similar frames: Pickler.save at line 70 (1 times), Pickler.save at line 414 (1 times), _Pickler.save at line 554 (1 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:881, in _Pickler.save_tuple(self, obj)
#     879 if n <= 3 and self.proto >= 2:
#     880     for element in obj:
# --> 881         save(element)
#     882     # Subtle.  Same as in the big comment below.
#     883     if id(obj) in memo:
#
#     [... skipping similar frames: Pickler.save at line 70 (1 times), Pickler.save at line 414 (1 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:966, in _Pickler.save_dict(self, obj)
#     963     self.write(MARK + DICT)
#     965 self.memoize(obj)
# --> 966 self._batch_setitems(obj.items())
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:74, in Pickler._batch_setitems(self, items)
#      72 def _batch_setitems(self, items):
#      73     if self._legacy_no_dict_keys_sorting:
# ---> 74         return super()._batch_setitems(items)
#      75     # Ignore the order of keys in a dict
#      76     try:
#      77         # Faster, but fails for unorderable elements
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:990, in _Pickler._batch_setitems(self, items)
#     988     for k, v in tmp:
#     989         save(k)
# --> 990         save(v)
#     991     write(SETITEMS)
#     992 elif n:
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\datasets\utils\_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File d:\jsn python\New folder\myemv\Lib\site-packages\dill\_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:572, in _Pickler.save(self, obj, save_persistent_id)
#     570 reduce = getattr(obj, "__reduce_ex__", None)
#     571 if reduce is not None:
# --> 572     rv = reduce(self.proto)
#     573 else:
#     574     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle '_hashlib.HMAC' object
